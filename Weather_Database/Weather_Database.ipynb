# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from scipy.stats import linregress

# Import the time library and datetime module from the datetime library
import time
from datetime import datetime

#Import requests library and api keys
import requests

import sys
sys.path.append("..")
from config import weather_api_key

# %%
# Create a set of 1500 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
# You can only unzip a zipped tuple once before it is removed from the computer's memory.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 788

# %%
# URL for API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the log start
print("Beginning data retrieval")
print("------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through list of cities
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
        time.sleep(10)
        
    # Create endpoint url for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing record {record_count} of set {set_count} | {city}")
    
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc
                         })

    # If an error is experienced, skip the city.
    except Exception as e:
        print(f"Exception of type {e} has occurred: {city} data not returned. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning data retrieval
# ------------------------
# Processing record 1 of set 1 | ushuaia
# Processing record 2 of set 1 | vaini
# Processing record 3 of set 1 | dikson
# Processing record 4 of set 1 | mount darwin
# Processing record 5 of set 1 | kodiak
# Processing record 6 of set 1 | baruun-urt
# Processing record 7 of set 1 | dolores
# Processing record 8 of set 1 | toliary
# Exception of type 'coord' has occurred: toliary not found. Skipping...
# Processing record 9 of set 1 | albany
# Processing record 10 of set 1 | chuy
# Processing record 11 of set 1 | irece
# Processing record 12 of set 1 | atuona
# Processing record 13 of set 1 | arraial do cabo
# Processing record 14 of set 1 | beisfjord
# Processing record 15 of set 1 | rikitea
# Processing record 16 of set 1 | puerto ayora
# Processing record 17 of set 1 | marystown
# Processing record 18 of set 1 | castro
# Processing record 19 of set 1 | narsaq
# Processing record 20 of set 1 | new norfolk
# Processing record 21 of set 1 | taree
# Processing record 22 of set 1 | smithers
# Processing record 23 of set 1 | georgetown
# Processing record 24 of set 1 | sistranda
# Processing record 25 of set 1 | dunedin
# Processing record 26 of set 1 | punta arenas
# Processing record 27 of set 1 | okha
# Processing record 28 of set 1 | sao filipe
# Processing record 29 of set 1 | biak
# Processing record 30 of set 1 | fallon
# Processing record 31 of set 1 | mataura
# Processing record 32 of set 1 | manicore
# Processing record 33 of set 1 | dingle
# Processing record 34 of set 1 | nizhneyansk
# Exception of type 'coord' has occurred: nizhneyansk not found. Skipping...
# Processing record 35 of set 1 | busselton
# Processing record 36 of set 1 | oriximina
# Processing record 37 of set 1 | kapaa
# Processing record 38 of set 1 | namatanai
# Processing record 39 of set 1 | port alfred
# Processing record 40 of set 1 | vila franca do campo
# Processing record 41 of set 1 | sentyabrskiy
# Exception of type 'coord' has occurred: sentyabrskiy not found. Skipping...
# Processing record 42 of set 1 | bluff
# Processing record 43 of set 1 | bubaque
# Processing record 44 of set 1 | laguna
# Processing record 45 of set 1 | edd
# Processing record 46 of set 1 | capreol
# Processing record 47 of set 1 | fortuna
# Processing record 48 of set 1 | andenes
# Processing record 49 of set 1 | bredasdorp
# Processing record 50 of set 1 | kununurra
# Processing record 52 of set 2 | sajalices
# Processing record 53 of set 2 | san ignacio
# Processing record 54 of set 2 | saint anthony
# Processing record 55 of set 2 | cape town
# Processing record 56 of set 2 | san rafael
# Processing record 57 of set 2 | isangel
# Processing record 58 of set 2 | tasiilaq
# Processing record 59 of set 2 | hilo
# Processing record 60 of set 2 | lebu
# Processing record 61 of set 2 | mount gambier
# Processing record 62 of set 2 | felanitx
# Processing record 63 of set 2 | jiuquan
# Processing record 64 of set 2 | mizdah
# Processing record 65 of set 2 | godda
# Processing record 66 of set 2 | ugento
# Processing record 67 of set 2 | san cristobal
# Processing record 68 of set 2 | narok
# Processing record 69 of set 2 | vanimo
# Processing record 70 of set 2 | hermanus
# Processing record 71 of set 2 | kurchum
# Processing record 72 of set 2 | tuktoyaktuk
# Processing record 73 of set 2 | manacapuru
# Processing record 74 of set 2 | bata
# Processing record 75 of set 2 | taolanaro
# Exception of type 'coord' has occurred: taolanaro not found. Skipping...
# Processing record 76 of set 2 | ponta do sol
# Processing record 77 of set 2 | utiroa
# Exception of type 'coord' has occurred: utiroa not found. Skipping...
# Processing record 78 of set 2 | rapid valley
# Processing record 79 of set 2 | touros
# Processing record 80 of set 2 | butaritari
# Processing record 81 of set 2 | amderma
# Exception of type 'coord' has occurred: amderma not found. Skipping...
# Processing record 82 of set 2 | souillac
# Processing record 83 of set 2 | belushya guba
# Exception of type 'coord' has occurred: belushya guba not found. Skipping...
# Processing record 84 of set 2 | yellowknife
# Processing record 85 of set 2 | barentsburg
# Exception of type 'coord' has occurred: barentsburg not found. Skipping...
# Processing record 86 of set 2 | thompson
# Processing record 87 of set 2 | marzuq
# Processing record 88 of set 2 | pevek
# Processing record 89 of set 2 | constitucion
# Processing record 90 of set 2 | paamiut
# Processing record 91 of set 2 | adolfo lopez mateos
# Processing record 92 of set 2 | tamandare
# Processing record 93 of set 2 | ostrovnoy
# Processing record 94 of set 2 | barrow
# Processing record 95 of set 2 | vao
# Processing record 96 of set 2 | ribeira grande
# Processing record 97 of set 2 | esperance
# Processing record 98 of set 2 | fort-shevchenko
# Processing record 99 of set 2 | qaanaaq
# Processing record 100 of set 2 | bulgan
# Processing record 101 of set 2 | zhanatas
# Exception of type 'coord' has occurred: zhanatas not found. Skipping...
# Processing record 103 of set 3 | san jose
# Processing record 104 of set 3 | plettenberg bay
# Processing record 105 of set 3 | mys shmidta
# Exception of type 'coord' has occurred: mys shmidta not found. Skipping...
# Processing record 106 of set 3 | saint-philippe
# Processing record 107 of set 3 | novo aripuana
# Processing record 108 of set 3 | ahipara
# Processing record 109 of set 3 | tabulbah
# Exception of type 'coord' has occurred: tabulbah not found. Skipping...
# Processing record 110 of set 3 | barsana
# Processing record 111 of set 3 | tres arroyos
# Processing record 112 of set 3 | balabac
# Processing record 113 of set 3 | svetlogorsk
# Processing record 114 of set 3 | mount isa
# Processing record 115 of set 3 | norman wells
# Processing record 116 of set 3 | nanortalik
# Processing record 117 of set 3 | east london
# Processing record 118 of set 3 | lumphat
# Processing record 119 of set 3 | rosetown
# Processing record 120 of set 3 | puerto leguizamo
# Processing record 121 of set 3 | honningsvag
# Processing record 122 of set 3 | alofi
# Processing record 123 of set 3 | yaan
# Processing record 124 of set 3 | upernavik
# Processing record 125 of set 3 | longyearbyen
# Processing record 126 of set 3 | kavieng
# Processing record 127 of set 3 | lima
# Processing record 128 of set 3 | krasnoselkup
# Processing record 129 of set 3 | beloha
# Processing record 130 of set 3 | ilulissat
# Processing record 131 of set 3 | dom pedro
# Processing record 132 of set 3 | avera
# Processing record 133 of set 3 | tiksi
# Processing record 134 of set 3 | bolungarvik
# Exception of type 'coord' has occurred: bolungarvik not found. Skipping...
# Processing record 135 of set 3 | blacksburg
# Processing record 136 of set 3 | balaipungut
# Processing record 137 of set 3 | sernur
# Processing record 138 of set 3 | alice springs
# Processing record 139 of set 3 | ugoofaaru
# Processing record 140 of set 3 | carnarvon
# Processing record 141 of set 3 | antipovka
# Processing record 142 of set 3 | hobart
# Processing record 143 of set 3 | jardim
# Processing record 144 of set 3 | praxedis guerrero
# Processing record 145 of set 3 | grindavik
# Processing record 146 of set 3 | meulaboh
# Processing record 147 of set 3 | savinskiy
# Processing record 148 of set 3 | haines junction
# Processing record 149 of set 3 | camopi
# Processing record 150 of set 3 | svetlyy
# Processing record 151 of set 3 | cherskiy
# Processing record 152 of set 3 | coahuayana
# Processing record 154 of set 4 | nome
# Processing record 155 of set 4 | andros town
# Processing record 156 of set 4 | chokurdakh
# Processing record 157 of set 4 | illoqqortoormiut
# Exception of type 'coord' has occurred: illoqqortoormiut not found. Skipping...
# Processing record 158 of set 4 | bengkulu
# Processing record 159 of set 4 | nikolskoye
# Processing record 160 of set 4 | naze
# Processing record 161 of set 4 | presidencia roque saenz pena
# Processing record 162 of set 4 | hamilton
# Processing record 163 of set 4 | los llanos de aridane
# Processing record 164 of set 4 | muisne
# Processing record 165 of set 4 | sokoto
# Processing record 166 of set 4 | tsabong
# Processing record 167 of set 4 | kidal
# Processing record 168 of set 4 | saryg-sep
# Processing record 169 of set 4 | karauzyak
# Exception of type 'coord' has occurred: karauzyak not found. Skipping...
# Processing record 170 of set 4 | magadan
# Processing record 171 of set 4 | chagda
# Exception of type 'coord' has occurred: chagda not found. Skipping...
# Processing record 172 of set 4 | mingyue
# Processing record 173 of set 4 | nkhata bay
# Processing record 174 of set 4 | agua verde
# Processing record 175 of set 4 | lakes entrance
# Processing record 176 of set 4 | bandarbeyla
# Processing record 177 of set 4 | hithadhoo
# Processing record 178 of set 4 | la ronge
# Processing record 179 of set 4 | bambous virieux
# Processing record 180 of set 4 | yantal
# Processing record 181 of set 4 | villiers
# Processing record 182 of set 4 | richards bay
# Processing record 183 of set 4 | birjand
# Processing record 184 of set 4 | rocky mountain house
# Processing record 185 of set 4 | ji-parana
# Exception of type 'coord' has occurred: ji-parana not found. Skipping...
# Processing record 186 of set 4 | jamestown
# Processing record 187 of set 4 | dubbo
# Processing record 188 of set 4 | mehamn
# Processing record 189 of set 4 | yara
# Processing record 190 of set 4 | maxixe
# Processing record 191 of set 4 | saint george
# Processing record 192 of set 4 | metehara
# Exception of type 'coord' has occurred: metehara not found. Skipping...
# Processing record 193 of set 4 | komsomolskiy
# Processing record 194 of set 4 | tambul
# Exception of type 'coord' has occurred: tambul not found. Skipping...
# Processing record 195 of set 4 | viron
# Processing record 196 of set 4 | torbay
# Processing record 197 of set 4 | port-gentil
# Processing record 198 of set 4 | kerki
# Exception of type 'coord' has occurred: kerki not found. Skipping...
# Processing record 199 of set 4 | victoria
# Processing record 200 of set 4 | tilichiki
# Processing record 201 of set 4 | buin
# Processing record 202 of set 4 | kaitangata
# Processing record 203 of set 4 | maymyo
# Processing record 205 of set 5 | saskylakh
# Processing record 206 of set 5 | port elizabeth
# Processing record 207 of set 5 | kuandian
# Processing record 208 of set 5 | manama
# Processing record 209 of set 5 | wladyslawowo
# Processing record 210 of set 5 | baykit
# Processing record 211 of set 5 | vaitupu
# Exception of type 'coord' has occurred: vaitupu not found. Skipping...
# Processing record 212 of set 5 | soderhamn
# Processing record 213 of set 5 | snasa
# Processing record 214 of set 5 | naryan-mar
# Processing record 215 of set 5 | andijon
# Processing record 216 of set 5 | yumen
# Processing record 217 of set 5 | sao joao da barra
# Processing record 218 of set 5 | warri
# Processing record 219 of set 5 | iqaluit
# Processing record 220 of set 5 | cidreira
# Processing record 221 of set 5 | luderitz
# Processing record 222 of set 5 | hasaki
# Processing record 223 of set 5 | fort nelson
# Processing record 224 of set 5 | xinyu
# Processing record 225 of set 5 | lemoore
# Processing record 226 of set 5 | kamenskoye
# Exception of type 'coord' has occurred: kamenskoye not found. Skipping...
# Processing record 227 of set 5 | tocoa
# Processing record 228 of set 5 | wagar
# Processing record 229 of set 5 | mangan
# Processing record 230 of set 5 | katsuura
# Processing record 231 of set 5 | havoysund
# Processing record 232 of set 5 | suoyarvi
# Processing record 233 of set 5 | klyuchi
# Processing record 234 of set 5 | macaboboni
# Exception of type 'coord' has occurred: macaboboni not found. Skipping...
# Processing record 235 of set 5 | hofn
# Processing record 236 of set 5 | puerto escondido
# Processing record 237 of set 5 | vardo
# Processing record 238 of set 5 | tsihombe
# Exception of type 'coord' has occurred: tsihombe not found. Skipping...
# Processing record 239 of set 5 | coquimbo
# Processing record 240 of set 5 | urumqi
# Processing record 241 of set 5 | namuac
# Processing record 242 of set 5 | avarua
# Processing record 243 of set 5 | balimo
# Exception of type 'coord' has occurred: balimo not found. Skipping...
# Processing record 244 of set 5 | tabou
# Processing record 245 of set 5 | matara
# Processing record 246 of set 5 | codrington
# Processing record 247 of set 5 | kachikau
# Exception of type 'coord' has occurred: kachikau not found. Skipping...
# Processing record 248 of set 5 | salalah
# Processing record 249 of set 5 | jingdezhen
# Processing record 250 of set 5 | jaguariaiva
# Processing record 251 of set 5 | mecca
# Processing record 252 of set 5 | lisieux
# Processing record 253 of set 5 | rognan
# Processing record 254 of set 5 | bucerias
# Processing record 256 of set 6 | mezen
# Processing record 257 of set 6 | tura
# Processing record 258 of set 6 | abnub
# Processing record 259 of set 6 | guerrero negro
# Processing record 260 of set 6 | chabahar
# Processing record 261 of set 6 | talnakh
# Processing record 262 of set 6 | mantua
# Processing record 263 of set 6 | cobija
# Processing record 264 of set 6 | gushikawa
# Processing record 265 of set 6 | sola
# Processing record 266 of set 6 | dhankuta
# Processing record 267 of set 6 | russell
# Processing record 268 of set 6 | acapulco
# Processing record 269 of set 6 | trat
# Processing record 270 of set 6 | nabire
# Processing record 271 of set 6 | san quintin
# Processing record 272 of set 6 | arlit
# Processing record 273 of set 6 | geraldton
# Processing record 274 of set 6 | cabo san lucas
# Processing record 275 of set 6 | nagua
# Processing record 276 of set 6 | gamboma
# Processing record 277 of set 6 | umm kaddadah
# Processing record 278 of set 6 | rocha
# Processing record 279 of set 6 | provideniya
# Processing record 280 of set 6 | santa cruz do sul
# Processing record 281 of set 6 | turbat
# Processing record 282 of set 6 | shimoda
# Processing record 283 of set 6 | lucea
# Processing record 284 of set 6 | chebenki
# Processing record 285 of set 6 | khatanga
# Processing record 286 of set 6 | ibra
# Processing record 287 of set 6 | banda aceh
# Processing record 288 of set 6 | mar del plata
# Processing record 289 of set 6 | nan
# Processing record 290 of set 6 | klaksvik
# Processing record 291 of set 6 | leshukonskoye
# Processing record 292 of set 6 | akyab
# Processing record 293 of set 6 | brae
# Processing record 294 of set 6 | zambezi
# Processing record 295 of set 6 | chivay
# Processing record 296 of set 6 | ixtapa
# Processing record 297 of set 6 | asind
# Processing record 298 of set 6 | impfondo
# Processing record 299 of set 6 | guangyuan
# Processing record 300 of set 6 | tabuk
# Processing record 301 of set 6 | lata
# Processing record 302 of set 6 | litoral del san juan
# Exception of type 'coord' has occurred: litoral del san juan not found. Skipping...
# Processing record 303 of set 6 | alipur duar
# Exception of type 'coord' has occurred: alipur duar not found. Skipping...
# Processing record 304 of set 6 | clyde river
# Processing record 305 of set 6 | mahebourg
# Processing record 307 of set 7 | pisco
# Processing record 308 of set 7 | tete
# Processing record 309 of set 7 | kysyl-syr
# Processing record 310 of set 7 | mushie
# Processing record 311 of set 7 | tezu
# Processing record 312 of set 7 | assiniboia
# Processing record 313 of set 7 | methala
# Processing record 314 of set 7 | tromso
# Processing record 315 of set 7 | opava
# Processing record 316 of set 7 | shumikha
# Processing record 317 of set 7 | yingkou
# Processing record 318 of set 7 | iranshahr
# Processing record 319 of set 7 | cody
# Processing record 320 of set 7 | weatherford
# Processing record 321 of set 7 | hami
# Processing record 322 of set 7 | dukat
# Processing record 323 of set 7 | flinders
# Processing record 324 of set 7 | coolum beach
# Processing record 325 of set 7 | kahului
# Processing record 326 of set 7 | dhidhdhoo
# Processing record 327 of set 7 | comalcalco
# Processing record 328 of set 7 | bilibino
# Processing record 329 of set 7 | airai
# Processing record 330 of set 7 | prainha
# Processing record 331 of set 7 | merauke
# Processing record 332 of set 7 | dukhovnitskoye
# Processing record 333 of set 7 | saldanha
# Processing record 334 of set 7 | sonoita
# Processing record 335 of set 7 | vilyuysk
# Processing record 336 of set 7 | tupik
# Processing record 337 of set 7 | husavik
# Processing record 338 of set 7 | houma
# Processing record 339 of set 7 | requena
# Processing record 340 of set 7 | augusto correa
# Processing record 341 of set 7 | rawson
# Processing record 342 of set 7 | bargal
# Exception of type 'coord' has occurred: bargal not found. Skipping...
# Processing record 343 of set 7 | gazimurskiy zavod
# Processing record 344 of set 7 | haimen
# Processing record 345 of set 7 | poum
# Processing record 346 of set 7 | faanui
# Processing record 347 of set 7 | vanavara
# Processing record 348 of set 7 | nouakchott
# Processing record 349 of set 7 | macedo de cavaleiros
# Processing record 350 of set 7 | ulundi
# Processing record 351 of set 7 | vostok
# Processing record 352 of set 7 | bethel
# Processing record 353 of set 7 | margate
# Processing record 354 of set 7 | nam dinh
# Processing record 355 of set 7 | northam
# Processing record 356 of set 7 | yatou
# Processing record 358 of set 8 | belmonte
# Processing record 359 of set 8 | abha
# Processing record 360 of set 8 | haibowan
# Exception of type 'coord' has occurred: haibowan not found. Skipping...
# Processing record 361 of set 8 | saint-francois
# Processing record 362 of set 8 | jacareacanga
# Processing record 363 of set 8 | decatur
# Processing record 364 of set 8 | singaraja
# Processing record 365 of set 8 | carutapera
# Processing record 366 of set 8 | marsa matruh
# Processing record 367 of set 8 | tumannyy
# Exception of type 'coord' has occurred: tumannyy not found. Skipping...
# Processing record 368 of set 8 | alexander city
# Processing record 369 of set 8 | taoudenni
# Processing record 370 of set 8 | gryazi
# Processing record 371 of set 8 | leningradskiy
# Processing record 372 of set 8 | tadine
# Processing record 373 of set 8 | lae
# Processing record 374 of set 8 | hobyo
# Processing record 375 of set 8 | rolante
# Processing record 376 of set 8 | nenjiang
# Processing record 377 of set 8 | borovoy
# Processing record 378 of set 8 | buldana
# Processing record 379 of set 8 | baie-comeau
# Processing record 380 of set 8 | umzimvubu
# Exception of type 'coord' has occurred: umzimvubu not found. Skipping...
# Processing record 381 of set 8 | filadelfia
# Processing record 382 of set 8 | odweyne
# Processing record 383 of set 8 | sioux lookout
# Processing record 384 of set 8 | korla
# Processing record 385 of set 8 | bantou
# Processing record 386 of set 8 | port hueneme
# Processing record 387 of set 8 | yetkul
# Processing record 388 of set 8 | biltine
# Processing record 389 of set 8 | falmouth
# Processing record 390 of set 8 | shache
# Processing record 391 of set 8 | sept-iles
# Processing record 392 of set 8 | humaita
# Processing record 393 of set 8 | bolshegrivskoye
# Exception of type 'coord' has occurred: bolshegrivskoye not found. Skipping...
# Processing record 394 of set 8 | makakilo city
# Processing record 395 of set 8 | aswan
# Processing record 396 of set 8 | cabedelo
# Processing record 397 of set 8 | adrar
# Processing record 398 of set 8 | berlevag
# Processing record 399 of set 8 | trinidad
# Processing record 400 of set 8 | chapada dos guimaraes
# Processing record 401 of set 8 | san juan
# Processing record 402 of set 8 | conceicao da barra
# Processing record 403 of set 8 | osa
# Processing record 404 of set 8 | necochea
# Processing record 405 of set 8 | betare oya
# Processing record 406 of set 8 | ngukurr
# Exception of type 'coord' has occurred: ngukurr not found. Skipping...
# Processing record 407 of set 8 | pacific grove
# Processing record 409 of set 9 | amapa
# Processing record 410 of set 9 | moses lake
# Processing record 411 of set 9 | namibe
# Processing record 412 of set 9 | oeiras
# Processing record 413 of set 9 | phuket
# Processing record 414 of set 9 | benghazi
# Processing record 415 of set 9 | katherine
# Processing record 416 of set 9 | juneau
# Processing record 417 of set 9 | mesopotamia
# Processing record 418 of set 9 | pitimbu
# Processing record 419 of set 9 | kristiinankaupunki
# Processing record 420 of set 9 | eyl
# Processing record 421 of set 9 | xiangdong
# Exception of type 'coord' has occurred: xiangdong not found. Skipping...
# Processing record 422 of set 9 | ucluelet
# Processing record 423 of set 9 | puerto carreno
# Processing record 424 of set 9 | creston
# Processing record 425 of set 9 | chernyshevskiy
# Processing record 426 of set 9 | sorland
# Processing record 427 of set 9 | tucumcari
# Processing record 428 of set 9 | sembakung
# Processing record 429 of set 9 | lac du bonnet
# Processing record 430 of set 9 | pierre
# Processing record 431 of set 9 | kiama
# Processing record 432 of set 9 | shaartuz
# Exception of type 'coord' has occurred: shaartuz not found. Skipping...
# Processing record 433 of set 9 | pangnirtung
# Processing record 434 of set 9 | qaqortoq
# Processing record 435 of set 9 | elko
# Processing record 436 of set 9 | straumen
# Processing record 437 of set 9 | phan rang
# Exception of type 'coord' has occurred: phan rang not found. Skipping...
# Processing record 438 of set 9 | tuatapere
# Processing record 439 of set 9 | coihaique
# Processing record 440 of set 9 | minas
# Processing record 441 of set 9 | barinas
# Processing record 442 of set 9 | benguela
# Processing record 443 of set 9 | elbistan
# Processing record 444 of set 9 | maningrida
# Processing record 445 of set 9 | attawapiskat
# Exception of type 'coord' has occurred: attawapiskat not found. Skipping...
# Processing record 446 of set 9 | umm lajj
# Processing record 447 of set 9 | boddam
# Processing record 448 of set 9 | tobe
# Processing record 449 of set 9 | batemans bay
# Processing record 450 of set 9 | kavaratti
# Processing record 451 of set 9 | ishigaki
# Processing record 452 of set 9 | moose factory
# Processing record 453 of set 9 | champerico
# Processing record 454 of set 9 | malm
# Processing record 455 of set 9 | omboue
# Processing record 456 of set 9 | smirnykh
# Processing record 457 of set 9 | dicabisagan
# Processing record 458 of set 9 | tocantins
# Processing record 460 of set 10 | gat
# Processing record 461 of set 10 | ambodifototra
# Exception of type 'coord' has occurred: ambodifototra not found. Skipping...
# Processing record 462 of set 10 | port hardy
# Processing record 463 of set 10 | jiwani
# Processing record 464 of set 10 | lagoa
# Processing record 465 of set 10 | simbahan
# Processing record 466 of set 10 | ola
# Processing record 467 of set 10 | badou
# Processing record 468 of set 10 | christchurch
# Processing record 469 of set 10 | caravelas
# Processing record 470 of set 10 | giarre
# Processing record 471 of set 10 | ilka
# Exception of type 'coord' has occurred: ilka not found. Skipping...
# Processing record 472 of set 10 | gamba
# Processing record 473 of set 10 | labuan
# Processing record 474 of set 10 | bone
# Processing record 475 of set 10 | oussouye
# Processing record 476 of set 10 | muros
# Processing record 477 of set 10 | ancud
# Processing record 478 of set 10 | pyay
# Processing record 479 of set 10 | chaman
# Processing record 480 of set 10 | sorvag
# Exception of type 'coord' has occurred: sorvag not found. Skipping...
# Processing record 481 of set 10 | port lincoln
# Processing record 482 of set 10 | kruisfontein
# Processing record 483 of set 10 | tevaitoa
# Processing record 484 of set 10 | freeport
# Processing record 485 of set 10 | aliganj
# Processing record 486 of set 10 | gobabis
# Processing record 487 of set 10 | vaitape
# Processing record 488 of set 10 | niteroi
# Processing record 489 of set 10 | san jeronimo
# Processing record 490 of set 10 | zhigansk
# Processing record 491 of set 10 | alihe
# Processing record 492 of set 10 | nurota
# Processing record 493 of set 10 | eureka
# Processing record 494 of set 10 | albanel
# Processing record 495 of set 10 | makokou
# Processing record 496 of set 10 | hlatikulu
# Processing record 497 of set 10 | ketchikan
# Processing record 498 of set 10 | outlook
# Processing record 499 of set 10 | aklavik
# Processing record 500 of set 10 | raudeberg
# Processing record 501 of set 10 | graz
# Processing record 502 of set 10 | nalut
# Processing record 503 of set 10 | portland
# Processing record 504 of set 10 | vanino
# Processing record 505 of set 10 | youghal
# Processing record 506 of set 10 | vytegra
# Processing record 507 of set 10 | alta
# Processing record 508 of set 10 | funadhoo
# Processing record 509 of set 10 | kolosovka
# Processing record 511 of set 11 | cumaribo
# Exception of type 'coord' has occurred: cumaribo not found. Skipping...
# Processing record 512 of set 11 | port macquarie
# Processing record 513 of set 11 | grand gaube
# Processing record 514 of set 11 | araouane
# Processing record 515 of set 11 | louisbourg
# Exception of type 'coord' has occurred: louisbourg not found. Skipping...
# Processing record 516 of set 11 | manavalakurichi
# Processing record 517 of set 11 | bordighera
# Processing record 518 of set 11 | bambanglipuro
# Processing record 519 of set 11 | turukhansk
# Processing record 520 of set 11 | fremont
# Processing record 521 of set 11 | camapua
# Processing record 522 of set 11 | pervomayskoye
# Processing record 523 of set 11 | la roche-sur-yon
# Processing record 524 of set 11 | luau
# Processing record 525 of set 11 | rujiena
# Processing record 526 of set 11 | wasilla
# Processing record 527 of set 11 | jujuy
# Exception of type 'coord' has occurred: jujuy not found. Skipping...
# Processing record 528 of set 11 | jefferson city
# Processing record 529 of set 11 | byron bay
# Processing record 530 of set 11 | petropavlovsk-kamchatskiy
# Processing record 531 of set 11 | pandan
# Processing record 532 of set 11 | lazurne
# Processing record 533 of set 11 | pedasi
# Processing record 534 of set 11 | sobolevo
# Processing record 535 of set 11 | lompoc
# Processing record 536 of set 11 | mackay
# Processing record 537 of set 11 | zonguldak
# Processing record 538 of set 11 | lemesos
# Exception of type 'coord' has occurred: lemesos not found. Skipping...
# Processing record 539 of set 11 | bocas del toro
# Processing record 540 of set 11 | puerto rondon
# Processing record 541 of set 11 | port jervis
# Processing record 542 of set 11 | pacifica
# Processing record 543 of set 11 | lorengau
# Processing record 544 of set 11 | joshimath
# Processing record 545 of set 11 | severo-kurilsk
# Processing record 546 of set 11 | rock springs
# Processing record 547 of set 11 | vrangel
# Processing record 548 of set 11 | sungaipenuh
# Processing record 549 of set 11 | nishihara
# Processing record 550 of set 11 | itarema
# Processing record 551 of set 11 | mao
# Processing record 552 of set 11 | vestmannaeyjar
# Processing record 553 of set 11 | ilovlya
# Processing record 554 of set 11 | ossora
# Processing record 555 of set 11 | mikhaylovka
# Processing record 556 of set 11 | cuamba
# Processing record 557 of set 11 | liverpool
# Processing record 558 of set 11 | yar-sale
# Processing record 559 of set 11 | barceloneta
# Processing record 560 of set 11 | hervey bay
# Processing record 562 of set 12 | bereda
# Processing record 563 of set 12 | ampanihy
# Processing record 564 of set 12 | ashqelon
# Processing record 565 of set 12 | khonuu
# Exception of type 'coord' has occurred: khonuu not found. Skipping...
# Processing record 566 of set 12 | la uribe
# Exception of type 'coord' has occurred: la uribe not found. Skipping...
# Processing record 567 of set 12 | artesia
# Processing record 568 of set 12 | thaba-tseka
# Processing record 569 of set 12 | galiwinku
# Exception of type 'coord' has occurred: galiwinku not found. Skipping...
# Processing record 570 of set 12 | talakan
# Processing record 571 of set 12 | kpalime
# Processing record 572 of set 12 | boende
# Processing record 573 of set 12 | harper
# Processing record 574 of set 12 | olinda
# Processing record 575 of set 12 | broome
# Processing record 576 of set 12 | jaguarao
# Processing record 577 of set 12 | okhotsk
# Processing record 578 of set 12 | jaisalmer
# Processing record 579 of set 12 | san carlos de bariloche
# Processing record 580 of set 12 | nizhniy baskunchak
# Processing record 581 of set 12 | martapura
# Processing record 582 of set 12 | priyutnoye
# Processing record 583 of set 12 | nyurba
# Processing record 584 of set 12 | totness
# Processing record 585 of set 12 | one hundred mile house
# Exception of type 'coord' has occurred: one hundred mile house not found. Skipping...
# Processing record 586 of set 12 | dinajpur
# Processing record 587 of set 12 | mineros
# Processing record 588 of set 12 | ituni
# Exception of type 'coord' has occurred: ituni not found. Skipping...
# Processing record 589 of set 12 | kieta
# Processing record 590 of set 12 | daru
# Processing record 591 of set 12 | sorong
# Processing record 592 of set 12 | vila velha
# Processing record 593 of set 12 | hendek
# Processing record 594 of set 12 | nago
# Processing record 595 of set 12 | kavallarion
# Exception of type 'coord' has occurred: kavallarion not found. Skipping...
# Processing record 596 of set 12 | lively
# Processing record 597 of set 12 | buala
# Processing record 598 of set 12 | tororo
# Processing record 599 of set 12 | cheuskiny
# Exception of type 'coord' has occurred: cheuskiny not found. Skipping...
# Processing record 600 of set 12 | uchaly
# Processing record 601 of set 12 | ballina
# Processing record 602 of set 12 | sambava
# Processing record 603 of set 12 | lar gerd
# Exception of type 'coord' has occurred: lar gerd not found. Skipping...
# Processing record 604 of set 12 | xining
# Processing record 605 of set 12 | chertkovo
# Processing record 606 of set 12 | thinadhoo
# Processing record 607 of set 12 | samusu
# Exception of type 'coord' has occurred: samusu not found. Skipping...
# Processing record 608 of set 12 | escarcega
# Processing record 609 of set 12 | dorobantu
# Processing record 610 of set 12 | tautira
# Processing record 611 of set 12 | omsukchan
# Processing record 613 of set 13 | canutama
# Processing record 614 of set 13 | saint-pierre
# Processing record 615 of set 13 | maragogi
# Processing record 616 of set 13 | mildura
# Processing record 617 of set 13 | port augusta
# Processing record 618 of set 13 | ahuimanu
# Processing record 619 of set 13 | saleaula
# Exception of type 'coord' has occurred: saleaula not found. Skipping...
# Processing record 620 of set 13 | amga
# Processing record 621 of set 13 | olafsvik
# Processing record 622 of set 13 | riberalta
# Processing record 623 of set 13 | buraydah
# Processing record 624 of set 13 | skibbereen
# Processing record 625 of set 13 | asyut
# Processing record 626 of set 13 | lastoursville
# Processing record 627 of set 13 | alyangula
# Processing record 628 of set 13 | mgandu
# Processing record 629 of set 13 | cayenne
# Processing record 630 of set 13 | chapais
# Processing record 631 of set 13 | baculin
# Processing record 632 of set 13 | yarada
# Processing record 633 of set 13 | aboso
# Processing record 634 of set 13 | inhambane
# Processing record 635 of set 13 | auki
# Processing record 636 of set 13 | fez
# Processing record 637 of set 13 | fort wellington
# Processing record 638 of set 13 | verkhoyansk
# Processing record 639 of set 13 | kang
# Processing record 640 of set 13 | saint-augustin
# Processing record 641 of set 13 | miranda
# Processing record 642 of set 13 | severo-yeniseyskiy
# Processing record 643 of set 13 | egvekinot
# Processing record 644 of set 13 | lasa
# Processing record 645 of set 13 | olyka
# Processing record 646 of set 13 | azimur
# Exception of type 'coord' has occurred: azimur not found. Skipping...
# Processing record 647 of set 13 | santa rosa
# Processing record 648 of set 13 | murray bridge
# Processing record 649 of set 13 | hedensted
# Processing record 650 of set 13 | stettler
# Processing record 651 of set 13 | kloulklubed
# Processing record 652 of set 13 | tabriz
# Processing record 653 of set 13 | udachnyy
# Processing record 654 of set 13 | tazmalt
# Processing record 655 of set 13 | belize
# Processing record 656 of set 13 | charleston
# Processing record 657 of set 13 | palaikastron
# Processing record 658 of set 13 | bekhtery
# Processing record 659 of set 13 | gigmoto
# Processing record 660 of set 13 | senj
# Processing record 661 of set 13 | karratha
# Processing record 662 of set 13 | zhangjiakou
# Processing record 664 of set 14 | canakkale
# Processing record 665 of set 14 | waddan
# Processing record 666 of set 14 | mahon
# Processing record 667 of set 14 | ratnagiri
# Processing record 668 of set 14 | sumbe
# Processing record 669 of set 14 | shatsk
# Processing record 670 of set 14 | imeni poliny osipenko
# Processing record 671 of set 14 | marcona
# Exception of type 'coord' has occurred: marcona not found. Skipping...
# Processing record 672 of set 14 | hualmay
# Processing record 673 of set 14 | gaoua
# Processing record 674 of set 14 | millbrook
# Processing record 675 of set 14 | nantucket
# Processing record 676 of set 14 | kungalv
# Processing record 677 of set 14 | lovozero
# Processing record 678 of set 14 | boksitogorsk
# Processing record 679 of set 14 | kawalu
# Processing record 680 of set 14 | araure
# Processing record 681 of set 14 | yulara
# Processing record 682 of set 14 | samaipata
# Processing record 683 of set 14 | toma
# Processing record 684 of set 14 | maputo
# Processing record 685 of set 14 | mareeba
# Processing record 686 of set 14 | sahuaripa
# Processing record 687 of set 14 | itacare
# Processing record 688 of set 14 | taltal
# Processing record 689 of set 14 | mangai
# Processing record 690 of set 14 | beipiao
# Processing record 691 of set 14 | staunton
# Processing record 692 of set 14 | yenagoa
# Processing record 693 of set 14 | boshnyakovo
# Processing record 694 of set 14 | heers
# Processing record 695 of set 14 | tocopilla
# Processing record 696 of set 14 | ellsworth
# Processing record 697 of set 14 | upata
# Processing record 698 of set 14 | artyk
# Exception of type 'coord' has occurred: artyk not found. Skipping...
# Processing record 699 of set 14 | esmeraldas
# Processing record 700 of set 14 | zemio
# Processing record 701 of set 14 | ballarat
# Processing record 702 of set 14 | kuala lumpur
# Processing record 703 of set 14 | kikwit
# Processing record 704 of set 14 | camana
# Processing record 705 of set 14 | bridlington
# Processing record 706 of set 14 | college
# Processing record 707 of set 14 | tateyama
# Processing record 708 of set 14 | marfino
# Processing record 709 of set 14 | rio grande
# Processing record 710 of set 14 | wagga wagga
# Processing record 711 of set 14 | jumla
# Processing record 712 of set 14 | tamiahua
# Processing record 713 of set 14 | koungheul
# Processing record 715 of set 15 | grand river south east
# Exception of type 'coord' has occurred: grand river south east not found. Skipping...
# Processing record 716 of set 15 | cortez
# Processing record 717 of set 15 | miri
# Processing record 718 of set 15 | maniwaki
# Processing record 719 of set 15 | bhatkal
# Processing record 720 of set 15 | ipixuna
# Processing record 721 of set 15 | atar
# Processing record 722 of set 15 | maniitsoq
# Processing record 723 of set 15 | ponneri
# Processing record 724 of set 15 | sangar
# Processing record 725 of set 15 | aleksandrov gay
# Processing record 726 of set 15 | big spring
# Processing record 727 of set 15 | miles city
# Processing record 728 of set 15 | ouadda
# Processing record 729 of set 15 | novikovo
# Processing record 730 of set 15 | ambilobe
# Processing record 731 of set 15 | turochak
# Processing record 732 of set 15 | mafeteng
# Processing record 733 of set 15 | colares
# Processing record 734 of set 15 | krasnyy chikoy
# Processing record 735 of set 15 | kudahuvadhoo
# Processing record 736 of set 15 | beringovskiy
# Processing record 737 of set 15 | trairi
# Processing record 738 of set 15 | viedma
# Processing record 739 of set 15 | oranjemund
# Processing record 740 of set 15 | bay roberts
# Processing record 741 of set 15 | zholymbet
# Processing record 742 of set 15 | puerto pinasco
# Exception of type 'coord' has occurred: puerto pinasco not found. Skipping...
# Processing record 743 of set 15 | cockburn town
# Processing record 744 of set 15 | singapore
# Processing record 745 of set 15 | riyadh
# Processing record 746 of set 15 | ecoporanga
# Processing record 747 of set 15 | nushki
# Processing record 748 of set 15 | nador
# Processing record 749 of set 15 | poltavka
# Processing record 750 of set 15 | storm lake
# Processing record 751 of set 15 | saint-joseph
# Processing record 752 of set 15 | borogontsy
# Processing record 753 of set 15 | port hedland
# Processing record 754 of set 15 | rio de janeiro
# Processing record 755 of set 15 | algiers
# Processing record 756 of set 15 | padang
# Processing record 757 of set 15 | hukuntsi
# Processing record 758 of set 15 | bairiki
# Processing record 759 of set 15 | anadyr
# Processing record 760 of set 15 | mitsamiouli
# Processing record 761 of set 15 | maloshuyka
# Exception of type 'coord' has occurred: maloshuyka not found. Skipping...
# Processing record 762 of set 15 | taseyevo
# Processing record 763 of set 15 | wanaka
# Processing record 764 of set 15 | gizo
# Processing record 766 of set 16 | onega
# Processing record 767 of set 16 | kurayoshi
# Processing record 768 of set 16 | srednekolymsk
# Processing record 769 of set 16 | tevriz
# Processing record 770 of set 16 | san policarpo
# Processing record 771 of set 16 | shubarkuduk
# Processing record 772 of set 16 | faya
# Processing record 773 of set 16 | bloomingdale
# Processing record 774 of set 16 | salamiyah
# Processing record 775 of set 16 | sibolga
# Processing record 776 of set 16 | awbari
# Processing record 777 of set 16 | tungor
# Processing record 778 of set 16 | popondetta
# Processing record 779 of set 16 | sao gabriel da cachoeira
# Processing record 780 of set 16 | cabinda
# Processing record 781 of set 16 | lincoln
# Processing record 782 of set 16 | gangotri
# Exception of type 'coord' has occurred: gangotri not found. Skipping...
# Processing record 783 of set 16 | otavi
# Processing record 784 of set 16 | roald
# Processing record 785 of set 16 | kitimat
# Processing record 786 of set 16 | chitrakonda
# Processing record 787 of set 16 | yialos
# Exception of type 'coord' has occurred: yialos not found. Skipping...
# Processing record 788 of set 16 | iskateley
# Processing record 789 of set 16 | iguape
# Processing record 790 of set 16 | charlestown
# Processing record 791 of set 16 | nandurbar
# Processing record 792 of set 16 | oyama
# Processing record 793 of set 16 | port blair
# Processing record 794 of set 16 | emerald
# Processing record 795 of set 16 | quang ngai
# Processing record 796 of set 16 | xuddur
# Processing record 797 of set 16 | mana
# Processing record 798 of set 16 | mountain home
# Processing record 799 of set 16 | mahibadhoo
# Processing record 800 of set 16 | manokwari
# Processing record 801 of set 16 | hellvik
# Processing record 802 of set 16 | semey
# Processing record 803 of set 16 | borodino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries into a data frame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     33.04        78          74
# 1         Vaini      TO -21.2000 -175.2000     77.16        69          20
# 2        Dikson      RU  73.5069   80.5464     15.12        77           7
# 3  Mount Darwin      ZW -16.7725   31.5838     69.46        58          99
# 4        Kodiak      US  57.7900 -152.4072     36.91        93         100
# 5    Baruun-Urt      MN  46.6806  113.2792     40.91        55          95
# 6       Dolores      AR -36.3132  -57.6792     53.10        48           0
# 7        Albany      US  42.6001  -73.9662     39.58        49          42
# 8          Chuy      UY -33.6971  -53.4616     60.17        86         100
# 9         Irece      BR -11.3042  -41.8558     79.14        47         100
#
#    Wind Speed Current Description
# 0        4.97       broken clouds
# 1       11.50          few clouds
# 2       20.00           clear sky
# 3        4.32     overcast clouds
# 4        4.61     overcast clouds
# 5       21.14     overcast clouds
# 6       11.86           clear sky
# 7        5.01    scattered clouds
# 8        6.91     overcast clouds
# 9       16.22     overcast clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
