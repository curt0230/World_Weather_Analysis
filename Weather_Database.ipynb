# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from scipy.stats import linregress

# Import the time library and datetime module from the datetime library
import time
from datetime import datetime

#Import requests library and api keys
import requests
from config import weather_api_key

# %%
# Create a set of 1500 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
# You can only unzip a zipped tuple once before it is removed from the computer's memory.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# URL for API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the log start
print("Beginning data retrieval")
print("------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through list of cities
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
        time.sleep(10)
        
    # Create endpoint url for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing record {record_count} of set {set_count} | {city}")
    
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc
                         })

    # If an error is experienced, skip the city.
    except Exception as e:
        print(f"Exception of type {e} has occurred: {city} not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning data retrieval
# ------------------------
# Processing record 1 of set 1 | prince rupert
# Processing record 2 of set 1 | mataura
# Processing record 3 of set 1 | kapaa
# Processing record 4 of set 1 | ponta do sol
# Processing record 5 of set 1 | formoso do araguaia
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=formoso+do+araguaia
# Processing record 6 of set 1 | norman wells
# Processing record 7 of set 1 | hobart
# Processing record 8 of set 1 | pevek
# Processing record 9 of set 1 | hami
# Processing record 10 of set 1 | saint george
# Processing record 11 of set 1 | hilo
# Processing record 12 of set 1 | busselton
# Processing record 13 of set 1 | atar
# Processing record 14 of set 1 | stokmarknes
# Processing record 15 of set 1 | luderitz
# Processing record 16 of set 1 | punta arenas
# Processing record 17 of set 1 | provideniya
# Processing record 18 of set 1 | ushuaia
# Processing record 19 of set 1 | geraldton
# Processing record 20 of set 1 | bluff
# Processing record 21 of set 1 | amot
# Processing record 22 of set 1 | goderich
# Processing record 23 of set 1 | mouila
# Processing record 24 of set 1 | vaini
# Processing record 25 of set 1 | bontang
# Processing record 26 of set 1 | cape town
# Processing record 27 of set 1 | kavieng
# Processing record 28 of set 1 | chuy
# Processing record 29 of set 1 | yagodnoye
# Processing record 30 of set 1 | vaitupu
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=vaitupu
# Processing record 31 of set 1 | saldanha
# Processing record 32 of set 1 | thompson
# Processing record 33 of set 1 | mantena
# Processing record 34 of set 1 | butaritari
# Processing record 35 of set 1 | conceicao do araguaia
# Processing record 36 of set 1 | taolanaro
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=taolanaro
# Processing record 37 of set 1 | rodrigues alves
# Processing record 38 of set 1 | hermanus
# Processing record 39 of set 1 | east london
# Processing record 40 of set 1 | alice springs
# Processing record 41 of set 1 | albany
# Processing record 42 of set 1 | nizhneyansk
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=nizhneyansk
# Processing record 43 of set 1 | bethel
# Processing record 44 of set 1 | illoqqortoormiut
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=illoqqortoormiut
# Processing record 45 of set 1 | fukue
# Processing record 46 of set 1 | asosa
# Processing record 47 of set 1 | yarada
# Processing record 48 of set 1 | sarh
# Processing record 49 of set 1 | bukama
# Processing record 50 of set 1 | rikitea
# Processing record 52 of set 2 | lebu
# Processing record 53 of set 2 | isangel
# Processing record 54 of set 2 | rudolstadt
# Processing record 55 of set 2 | oranjemund
# Processing record 56 of set 2 | lazaro cardenas
# Processing record 57 of set 2 | kenai
# Processing record 58 of set 2 | alvaraes
# Processing record 59 of set 2 | yellowknife
# Processing record 60 of set 2 | mulchen
# Processing record 61 of set 2 | sidi ali
# Processing record 62 of set 2 | clyde river
# Processing record 63 of set 2 | bengkulu
# Processing record 64 of set 2 | ketchikan
# Processing record 65 of set 2 | puerto ayora
# Processing record 66 of set 2 | dovolnoye
# Processing record 67 of set 2 | hobyo
# Processing record 68 of set 2 | severo-kurilsk
# Processing record 69 of set 2 | georgetown
# Processing record 70 of set 2 | marystown
# Processing record 71 of set 2 | narsaq
# Processing record 72 of set 2 | saint-philippe
# Processing record 73 of set 2 | tuktoyaktuk
# Processing record 74 of set 2 | oussouye
# Processing record 75 of set 2 | tawkar
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=tawkar
# Processing record 76 of set 2 | kurchum
# Processing record 77 of set 2 | macaboboni
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=macaboboni
# Processing record 78 of set 2 | husavik
# Processing record 79 of set 2 | port hardy
# Processing record 80 of set 2 | jamestown
# Processing record 81 of set 2 | mys shmidta
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=mys+shmidta
# Processing record 82 of set 2 | vestmanna
# Processing record 83 of set 2 | kodiak
# Processing record 84 of set 2 | mutsamudu
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=mutsamudu
# Processing record 85 of set 2 | moranbah
# Processing record 86 of set 2 | virginia beach
# Processing record 87 of set 2 | kavaratti
# Processing record 88 of set 2 | vao
# Processing record 89 of set 2 | presidencia roque saenz pena
# Processing record 90 of set 2 | pontianak
# Processing record 91 of set 2 | nikolskoye
# Processing record 92 of set 2 | hamilton
# Processing record 93 of set 2 | eydhafushi
# Processing record 94 of set 2 | arraial do cabo
# Processing record 95 of set 2 | vallenar
# Processing record 96 of set 2 | belyy yar
# Processing record 97 of set 2 | dikson
# Processing record 98 of set 2 | bambous virieux
# Processing record 99 of set 2 | bani
# Processing record 100 of set 2 | matara
# Processing record 101 of set 2 | port elizabeth
# Processing record 103 of set 3 | faanui
# Processing record 104 of set 3 | guerrero negro
# Processing record 105 of set 3 | new norfolk
# Processing record 106 of set 3 | sao felix do xingu
# Processing record 107 of set 3 | shizunai
# Processing record 108 of set 3 | kununurra
# Processing record 109 of set 3 | port alfred
# Processing record 110 of set 3 | chokurdakh
# Processing record 111 of set 3 | grand river south east
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=grand+river+south+east
# Processing record 112 of set 3 | carnarvon
# Processing record 113 of set 3 | matagami
# Processing record 114 of set 3 | angangxi
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=angangxi
# Processing record 115 of set 3 | tambura
# Processing record 116 of set 3 | kumano
# Processing record 117 of set 3 | codrington
# Processing record 118 of set 3 | nchelenge
# Processing record 119 of set 3 | charters towers
# Processing record 120 of set 3 | lompoc
# Processing record 121 of set 3 | iskateley
# Processing record 122 of set 3 | huilong
# Processing record 123 of set 3 | okandja
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=okandja
# Processing record 124 of set 3 | cherskiy
# Processing record 125 of set 3 | oktyabrskoye
# Processing record 126 of set 3 | los llanos de aridane
# Processing record 127 of set 3 | klaksvik
# Processing record 128 of set 3 | bredasdorp
# Processing record 129 of set 3 | maragogi
# Processing record 130 of set 3 | nome
# Processing record 131 of set 3 | altagracia de orituco
# Processing record 132 of set 3 | ust-tsilma
# Processing record 133 of set 3 | bolungarvik
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=bolungarvik
# Processing record 134 of set 3 | ankazoabo
# Processing record 135 of set 3 | tasiilaq
# Processing record 136 of set 3 | cidreira
# Processing record 137 of set 3 | koutiala
# Processing record 138 of set 3 | hofn
# Processing record 139 of set 3 | marquetalia
# Processing record 140 of set 3 | pangnirtung
# Processing record 141 of set 3 | daru
# Processing record 142 of set 3 | atuona
# Processing record 143 of set 3 | margate
# Processing record 144 of set 3 | kawalu
# Processing record 145 of set 3 | tiksi
# Processing record 146 of set 3 | barentsburg
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=barentsburg
# Processing record 147 of set 3 | taburi
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=taburi
# Processing record 148 of set 3 | cayenne
# Processing record 149 of set 3 | acapulco
# Processing record 150 of set 3 | falealupo
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=falealupo
# Processing record 151 of set 3 | alofi
# Processing record 152 of set 3 | sur
# Processing record 154 of set 4 | majene
# Processing record 155 of set 4 | dauriya
# Processing record 156 of set 4 | sitka
# Processing record 157 of set 4 | effingham
# Processing record 158 of set 4 | concarneau
# Processing record 159 of set 4 | sentyabrskiy
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=sentyabrskiy
# Processing record 160 of set 4 | hithadhoo
# Processing record 161 of set 4 | lata
# Processing record 162 of set 4 | cabo san lucas
# Processing record 163 of set 4 | adre
# Processing record 164 of set 4 | ghanzi
# Processing record 165 of set 4 | egvekinot
# Processing record 166 of set 4 | novo aripuana
# Processing record 167 of set 4 | schweinfurt
# Processing record 168 of set 4 | newport
# Processing record 169 of set 4 | ostrovnoy
# Processing record 170 of set 4 | praia da vitoria
# Processing record 171 of set 4 | mansa
# Processing record 172 of set 4 | castro alves
# Processing record 173 of set 4 | richards bay
# Processing record 174 of set 4 | olafsvik
# Processing record 175 of set 4 | bunia
# Processing record 176 of set 4 | skibbereen
# Processing record 177 of set 4 | castro
# Processing record 178 of set 4 | byron bay
# Processing record 179 of set 4 | constitucion
# Processing record 180 of set 4 | sechura
# Processing record 181 of set 4 | ogulin
# Processing record 182 of set 4 | saransk
# Processing record 183 of set 4 | sibut
# Processing record 184 of set 4 | rabo de peixe
# Processing record 185 of set 4 | bambanglipuro
# Processing record 186 of set 4 | iqaluit
# Processing record 187 of set 4 | khatanga
# Processing record 188 of set 4 | ribeira grande
# Processing record 189 of set 4 | tabiauea
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=tabiauea
# Processing record 190 of set 4 | namibe
# Processing record 191 of set 4 | torbay
# Processing record 192 of set 4 | tuatapere
# Processing record 193 of set 4 | santa isabel do rio negro
# Processing record 194 of set 4 | yeppoon
# Processing record 195 of set 4 | lolua
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=lolua
# Processing record 196 of set 4 | kruisfontein
# Processing record 197 of set 4 | attawapiskat
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=attawapiskat
# Processing record 198 of set 4 | santa rosa
# Processing record 199 of set 4 | balimo
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=balimo
# Processing record 200 of set 4 | cherdyn
# Processing record 201 of set 4 | miyako
# Processing record 202 of set 4 | saint-denis
# Processing record 203 of set 4 | kaitangata
# Processing record 205 of set 5 | samalaeulu
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=samalaeulu
# Processing record 206 of set 5 | roald
# Processing record 207 of set 5 | bargal
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=bargal
# Processing record 208 of set 5 | bedele
# Processing record 209 of set 5 | kattivakkam
# Processing record 210 of set 5 | esperance
# Processing record 211 of set 5 | westport
# Processing record 212 of set 5 | naze
# Processing record 213 of set 5 | karratha
# Processing record 214 of set 5 | qaanaaq
# Processing record 215 of set 5 | ferrol
# Processing record 216 of set 5 | palmer
# Processing record 217 of set 5 | umzimvubu
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=umzimvubu
# Processing record 218 of set 5 | padang
# Processing record 219 of set 5 | paradwip
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=paradwip
# Processing record 220 of set 5 | souillac
# Processing record 221 of set 5 | marinette
# Processing record 222 of set 5 | calmar
# Processing record 223 of set 5 | pedernales
# Processing record 224 of set 5 | san quintin
# Processing record 225 of set 5 | oakdale
# Processing record 226 of set 5 | maluso
# Processing record 227 of set 5 | kundiawa
# Processing record 228 of set 5 | zapotiltic
# Processing record 229 of set 5 | jalu
# Processing record 230 of set 5 | lokoja
# Processing record 231 of set 5 | tabuk
# Processing record 232 of set 5 | cururupu
# Processing record 233 of set 5 | kendari
# Processing record 234 of set 5 | north las vegas
# Processing record 235 of set 5 | zonguldak
# Processing record 236 of set 5 | kahului
# Processing record 237 of set 5 | sestu
# Processing record 238 of set 5 | kerrobert
# Processing record 239 of set 5 | lasa
# Processing record 240 of set 5 | tungkang
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=tungkang
# Processing record 241 of set 5 | havelock
# Processing record 242 of set 5 | pidhorodne
# Processing record 243 of set 5 | burkhala
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=burkhala
# Processing record 244 of set 5 | sao gabriel da cachoeira
# Processing record 245 of set 5 | avarua
# Processing record 246 of set 5 | nanortalik
# Processing record 247 of set 5 | lebork
# Processing record 248 of set 5 | tungor
# Processing record 249 of set 5 | blankenberge
# Processing record 250 of set 5 | moose factory
# Processing record 251 of set 5 | marrakesh
# Processing record 252 of set 5 | cabedelo
# Processing record 253 of set 5 | saint-joseph
# Processing record 254 of set 5 | waddan
# Processing record 256 of set 6 | warmbad
# Processing record 257 of set 6 | puerto escondido
# Processing record 258 of set 6 | jiddah
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=jiddah
# Processing record 259 of set 6 | cap malheureux
# Processing record 260 of set 6 | maningrida
# Processing record 261 of set 6 | neiafu
# Processing record 262 of set 6 | pahrump
# Processing record 263 of set 6 | kamenskoye
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=kamenskoye
# Processing record 264 of set 6 | belmonte
# Processing record 265 of set 6 | beian
# Processing record 266 of set 6 | warqla
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=warqla
# Processing record 267 of set 6 | rawah
# Processing record 268 of set 6 | kalabo
# Processing record 269 of set 6 | belushya guba
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=belushya+guba
# Processing record 270 of set 6 | riyadh
# Processing record 271 of set 6 | port lincoln
# Processing record 272 of set 6 | victor harbor
# Processing record 273 of set 6 | carndonagh
# Processing record 274 of set 6 | arman
# Processing record 275 of set 6 | arlit
# Processing record 276 of set 6 | babaeski
# Processing record 277 of set 6 | nuuk
# Processing record 278 of set 6 | ambon
# Processing record 279 of set 6 | nowy targ
# Processing record 280 of set 6 | humaita
# Processing record 281 of set 6 | suruc
# Processing record 282 of set 6 | mar del plata
# Processing record 283 of set 6 | batagay
# Processing record 284 of set 6 | lorengau
# Processing record 285 of set 6 | bara
# Processing record 286 of set 6 | muros
# Processing record 287 of set 6 | ilulissat
# Processing record 288 of set 6 | college
# Processing record 289 of set 6 | talnakh
# Processing record 290 of set 6 | rumoi
# Processing record 291 of set 6 | yonago
# Processing record 292 of set 6 | tilichiki
# Processing record 293 of set 6 | sao filipe
# Processing record 294 of set 6 | meulaboh
# Processing record 295 of set 6 | strezhevoy
# Processing record 296 of set 6 | tautira
# Processing record 297 of set 6 | polson
# Processing record 298 of set 6 | savannakhet
# Processing record 299 of set 6 | laguna
# Processing record 300 of set 6 | darnah
# Processing record 301 of set 6 | north charleston
# Processing record 302 of set 6 | dolinsk
# Processing record 303 of set 6 | barrow
# Processing record 304 of set 6 | miri
# Processing record 305 of set 6 | urulga
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=urulga
# Processing record 307 of set 7 | carballo
# Processing record 308 of set 7 | halkirk
# Processing record 309 of set 7 | bukachacha
# Processing record 310 of set 7 | plettenberg bay
# Processing record 311 of set 7 | kholtoson
# Processing record 312 of set 7 | tomatlan
# Processing record 313 of set 7 | rio gallegos
# Processing record 314 of set 7 | muravlenko
# Processing record 315 of set 7 | barrhead
# Processing record 316 of set 7 | mucurapo
# Processing record 317 of set 7 | grindavik
# Processing record 318 of set 7 | sao joao da barra
# Processing record 319 of set 7 | yangambi
# Processing record 320 of set 7 | nhulunbuy
# Processing record 321 of set 7 | yambio
# Processing record 322 of set 7 | biak
# Processing record 323 of set 7 | vostok
# Processing record 324 of set 7 | crotone
# Processing record 325 of set 7 | adrar
# Processing record 326 of set 7 | sungaipenuh
# Processing record 327 of set 7 | anadyr
# Processing record 328 of set 7 | woodward
# Processing record 329 of set 7 | tieling
# Processing record 330 of set 7 | krasnyy chikoy
# Processing record 331 of set 7 | ucluelet
# Processing record 332 of set 7 | les cayes
# Processing record 333 of set 7 | kristiinankaupunki
# Processing record 334 of set 7 | tangshan
# Processing record 335 of set 7 | hasaki
# Processing record 336 of set 7 | one hundred mile house
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=one+hundred+mile+house
# Processing record 337 of set 7 | mantua
# Processing record 338 of set 7 | cockburn town
# Processing record 339 of set 7 | beringovskiy
# Processing record 340 of set 7 | morondava
# Processing record 341 of set 7 | goure
# Processing record 342 of set 7 | abnub
# Processing record 343 of set 7 | tara
# Processing record 344 of set 7 | tukrah
# Processing record 345 of set 7 | guelavia
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=guelavia
# Processing record 346 of set 7 | victoria
# Processing record 347 of set 7 | sorong
# Processing record 348 of set 7 | saint-augustin
# Processing record 349 of set 7 | ladario
# Processing record 350 of set 7 | myitkyina
# Processing record 351 of set 7 | pittsburg
# Processing record 352 of set 7 | tazovskiy
# Processing record 353 of set 7 | lake saint louis
# Processing record 354 of set 7 | katsuura
# Processing record 355 of set 7 | komsomolskiy
# Processing record 356 of set 7 | srednekolymsk
# Processing record 358 of set 8 | san patricio
# Processing record 359 of set 8 | evensk
# Processing record 360 of set 8 | celestun
# Processing record 361 of set 8 | wilmington
# Processing record 362 of set 8 | fort nelson
# Processing record 363 of set 8 | zhigalovo
# Processing record 364 of set 8 | uyuni
# Processing record 365 of set 8 | garwa
# Processing record 366 of set 8 | sinegorye
# Processing record 367 of set 8 | hualmay
# Processing record 368 of set 8 | sydney mines
# Processing record 369 of set 8 | marcona
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=marcona
# Processing record 370 of set 8 | magnor
# Processing record 371 of set 8 | shimoda
# Processing record 372 of set 8 | tambacounda
# Processing record 373 of set 8 | dingle
# Processing record 374 of set 8 | tabas
# Processing record 375 of set 8 | yar-sale
# Processing record 376 of set 8 | bubaque
# Processing record 377 of set 8 | preobrazheniye
# Processing record 378 of set 8 | aykhal
# Processing record 379 of set 8 | kalga
# Processing record 380 of set 8 | port alberni
# Processing record 381 of set 8 | tateyama
# Processing record 382 of set 8 | tarudant
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=tarudant
# Processing record 383 of set 8 | lavrentiya
# Processing record 384 of set 8 | frontera
# Processing record 385 of set 8 | maldonado
# Processing record 386 of set 8 | upernavik
# Processing record 387 of set 8 | halalo
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=halalo
# Processing record 388 of set 8 | erenhot
# Processing record 389 of set 8 | zhigansk
# Processing record 390 of set 8 | airai
# Processing record 391 of set 8 | longyearbyen
# Processing record 392 of set 8 | nishihara
# Processing record 393 of set 8 | plattsburgh
# Processing record 394 of set 8 | vardo
# Processing record 395 of set 8 | tambo
# Processing record 396 of set 8 | bay city
# Processing record 397 of set 8 | port blair
# Processing record 398 of set 8 | brae
# Processing record 399 of set 8 | andrews
# Processing record 400 of set 8 | forio
# Processing record 401 of set 8 | mbanza-ngungu
# Processing record 402 of set 8 | sola
# Processing record 403 of set 8 | rutland
# Processing record 404 of set 8 | fort saint john
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=fort+saint+john
# Processing record 405 of set 8 | ambilobe
# Processing record 406 of set 8 | jiaonan
# Processing record 407 of set 8 | nouadhibou
# Processing record 409 of set 9 | ust-nera
# Processing record 410 of set 9 | marsh harbour
# Processing record 411 of set 9 | mattru
# Processing record 412 of set 9 | coahuayana
# Processing record 413 of set 9 | treinta y tres
# Processing record 414 of set 9 | bilma
# Processing record 415 of set 9 | ukiah
# Processing record 416 of set 9 | sept-iles
# Processing record 417 of set 9 | champerico
# Processing record 418 of set 9 | mahebourg
# Processing record 419 of set 9 | nantucket
# Processing record 420 of set 9 | surman
# Processing record 421 of set 9 | shache
# Processing record 422 of set 9 | batticaloa
# Processing record 423 of set 9 | poum
# Processing record 424 of set 9 | camacari
# Processing record 425 of set 9 | kapit
# Processing record 426 of set 9 | russell
# Processing record 427 of set 9 | shelburne
# Processing record 428 of set 9 | samusu
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=samusu
# Processing record 429 of set 9 | chornukhy
# Processing record 430 of set 9 | bayir
# Processing record 431 of set 9 | te anau
# Processing record 432 of set 9 | baruun-urt
# Processing record 433 of set 9 | ambodifototra
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=ambodifototra
# Processing record 434 of set 9 | marawi
# Processing record 435 of set 9 | umm lajj
# Processing record 436 of set 9 | saleaula
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=saleaula
# Processing record 437 of set 9 | macamic
# Processing record 438 of set 9 | zhezkazgan
# Processing record 439 of set 9 | okato
# Processing record 440 of set 9 | arrifes
# Processing record 441 of set 9 | kanker
# Processing record 442 of set 9 | finnsnes
# Processing record 443 of set 9 | san andres
# Processing record 444 of set 9 | araouane
# Processing record 445 of set 9 | koungou
# Processing record 446 of set 9 | soyo
# Processing record 447 of set 9 | san fernando
# Processing record 448 of set 9 | axim
# Processing record 449 of set 9 | sarankhola
# Processing record 450 of set 9 | bereda
# Processing record 451 of set 9 | vila velha
# Processing record 452 of set 9 | keti bandar
# Processing record 453 of set 9 | waitati
# Processing record 454 of set 9 | tanout
# Processing record 455 of set 9 | maloh
# Processing record 456 of set 9 | chunskiy
# Processing record 457 of set 9 | mareeba
# Processing record 458 of set 9 | saskylakh
# Processing record 460 of set 10 | lamu
# Processing record 461 of set 10 | rafai
# Processing record 462 of set 10 | sisimiut
# Processing record 463 of set 10 | salalah
# Processing record 464 of set 10 | fort saint james
# Processing record 465 of set 10 | kangaba
# Processing record 466 of set 10 | yuxia
# Processing record 467 of set 10 | harper
# Processing record 468 of set 10 | louisbourg
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=louisbourg
# Processing record 469 of set 10 | kargasok
# Processing record 470 of set 10 | tiznit
# Processing record 471 of set 10 | san juan de los morros
# Processing record 472 of set 10 | storforshei
# Processing record 473 of set 10 | bend
# Processing record 474 of set 10 | tabatinga
# Processing record 475 of set 10 | fourmies
# Processing record 476 of set 10 | moerai
# Processing record 477 of set 10 | pascagoula
# Processing record 478 of set 10 | grand gaube
# Processing record 479 of set 10 | pierre
# Processing record 480 of set 10 | kloulklubed
# Processing record 481 of set 10 | zolotinka
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=zolotinka
# Processing record 482 of set 10 | buariki
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=buariki
# Processing record 483 of set 10 | hambantota
# Processing record 484 of set 10 | dudinka
# Processing record 485 of set 10 | praia
# Processing record 486 of set 10 | novikovo
# Processing record 487 of set 10 | katakwi
# Processing record 488 of set 10 | taoudenni
# Processing record 489 of set 10 | davila
# Processing record 490 of set 10 | yavaros
# Processing record 491 of set 10 | novosheshminsk
# Processing record 492 of set 10 | bima
# Processing record 493 of set 10 | amderma
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=amderma
# Processing record 494 of set 10 | soe
# Processing record 495 of set 10 | gornyy
# Processing record 496 of set 10 | vagay
# Processing record 497 of set 10 | asnaes
# Processing record 498 of set 10 | aktash
# Processing record 499 of set 10 | thakurgaon
# Processing record 500 of set 10 | abu dhabi
# Processing record 501 of set 10 | muriwai beach
# Processing record 502 of set 10 | jaipur hat
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=jaipur+hat
# Processing record 503 of set 10 | vrangel
# Processing record 504 of set 10 | santa vitoria
# Processing record 505 of set 10 | tokur
# Processing record 506 of set 10 | saurimo
# Processing record 507 of set 10 | slupsk
# Processing record 508 of set 10 | puksoozero
# Processing record 509 of set 10 | tromso
# Processing record 511 of set 11 | matola
# Processing record 512 of set 11 | botro
# Processing record 513 of set 11 | yuzhno-yeniseyskiy
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=yuzhno-yeniseyskiy
# Processing record 514 of set 11 | pisco
# Processing record 515 of set 11 | buchmany
# Processing record 516 of set 11 | faya
# Processing record 517 of set 11 | slave lake
# Processing record 518 of set 11 | magherani
# Processing record 519 of set 11 | jambi
# Processing record 520 of set 11 | megion
# Processing record 521 of set 11 | keflavik
# Processing record 522 of set 11 | tsihombe
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=tsihombe
# Processing record 523 of set 11 | kumbo
# Processing record 524 of set 11 | paamiut
# Processing record 525 of set 11 | uige
# Processing record 526 of set 11 | roma
# Processing record 527 of set 11 | bonthe
# Processing record 528 of set 11 | karaton
# Processing record 529 of set 11 | aswan
# Processing record 530 of set 11 | pemangkat
# Processing record 531 of set 11 | kibre mengist
# Processing record 532 of set 11 | natal
# Processing record 533 of set 11 | farafenni
# Processing record 534 of set 11 | maryborough
# Processing record 535 of set 11 | forbes
# Processing record 536 of set 11 | flin flon
# Processing record 537 of set 11 | diffa
# Processing record 538 of set 11 | mamallapuram
# Processing record 539 of set 11 | boa viagem
# Processing record 540 of set 11 | bilibino
# Processing record 541 of set 11 | prieska
# Processing record 542 of set 11 | allapalli
# Processing record 543 of set 11 | vinh long
# Processing record 544 of set 11 | qasigiannguit
# Processing record 545 of set 11 | pyapon
# Processing record 546 of set 11 | merauke
# Processing record 547 of set 11 | canete
# Processing record 548 of set 11 | saint anthony
# Processing record 549 of set 11 | ponta delgada
# Processing record 550 of set 11 | umba
# Processing record 551 of set 11 | nynashamn
# Processing record 552 of set 11 | grande-riviere
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=grande-riviere
# Processing record 553 of set 11 | corner brook
# Processing record 554 of set 11 | iquique
# Processing record 555 of set 11 | vryheid
# Processing record 556 of set 11 | ariquemes
# Processing record 557 of set 11 | sri aman
# Processing record 558 of set 11 | sinnamary
# Processing record 559 of set 11 | zaria
# Processing record 560 of set 11 | manicore
# Processing record 562 of set 12 | kazalinsk
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=kazalinsk
# Processing record 563 of set 12 | kroya
# Processing record 564 of set 12 | sainte-marie
# Processing record 565 of set 12 | rio de janeiro
# Processing record 566 of set 12 | comodoro rivadavia
# Processing record 567 of set 12 | suicheng
# Processing record 568 of set 12 | saint-pierre
# Processing record 569 of set 12 | batouri
# Processing record 570 of set 12 | wewak
# Processing record 571 of set 12 | danbury
# Processing record 572 of set 12 | okakarara
# Processing record 573 of set 12 | omsukchan
# Processing record 574 of set 12 | kapoeta
# Processing record 575 of set 12 | borama
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=borama
# Processing record 576 of set 12 | yaan
# Processing record 577 of set 12 | san felipe
# Processing record 578 of set 12 | aripuana
# Processing record 579 of set 12 | denpasar
# Processing record 580 of set 12 | baiyin
# Processing record 581 of set 12 | tatawin
# Processing record 582 of set 12 | bur gabo
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=bur+gabo
# Processing record 583 of set 12 | dunedin
# Processing record 584 of set 12 | semirom
# Processing record 585 of set 12 | zhanatas
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=zhanatas
# Processing record 586 of set 12 | vila franca do campo
# Processing record 587 of set 12 | saint-francois
# Processing record 588 of set 12 | okhotsk
# Processing record 589 of set 12 | ntoum
# Processing record 590 of set 12 | lchashen
# Processing record 591 of set 12 | alotau
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=alotau
# Processing record 592 of set 12 | utiroa
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=utiroa
# Processing record 593 of set 12 | yining
# Processing record 594 of set 12 | tooele
# Processing record 595 of set 12 | alyangula
# Processing record 596 of set 12 | pacific grove
# Processing record 597 of set 12 | springbok
# Processing record 598 of set 12 | coquimbo
# Processing record 599 of set 12 | dingzhou
# Processing record 600 of set 12 | sterling
# Processing record 601 of set 12 | la palma
# Processing record 602 of set 12 | manado
# Processing record 603 of set 12 | xuddur
# Processing record 604 of set 12 | koluszki
# Processing record 605 of set 12 | san marcos de colon
# Processing record 606 of set 12 | kuche
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=kuche
# Processing record 607 of set 12 | kiama
# Processing record 608 of set 12 | shingu
# Processing record 609 of set 12 | paita
# Processing record 610 of set 12 | wuwei
# Processing record 611 of set 12 | andselv
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=andselv
# Processing record 613 of set 13 | juneau
# Processing record 614 of set 13 | lagoa
# Processing record 615 of set 13 | wanning
# Processing record 616 of set 13 | portland
# Processing record 617 of set 13 | traverse city
# Processing record 618 of set 13 | mecca
# Processing record 619 of set 13 | binga
# Processing record 620 of set 13 | alma
# Processing record 621 of set 13 | anjozorobe
# Processing record 622 of set 13 | bardiyah
# Processing record 623 of set 13 | guhagar
# Processing record 624 of set 13 | san ignacio
# Processing record 625 of set 13 | puro
# Processing record 626 of set 13 | nanakuli
# Processing record 627 of set 13 | tshane
# Processing record 628 of set 13 | lyuban
# Processing record 629 of set 13 | mae hong son
# Processing record 630 of set 13 | bialogard
# Processing record 631 of set 13 | alice town
# Processing record 632 of set 13 | todos santos
# Processing record 633 of set 13 | madison
# Processing record 634 of set 13 | masaka
# Processing record 635 of set 13 | karaul
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=karaul
# Processing record 636 of set 13 | kristiansund
# Processing record 637 of set 13 | coihueco
# Processing record 638 of set 13 | lubao
# Processing record 639 of set 13 | luancheng
# Processing record 640 of set 13 | pokosnoye
# Processing record 641 of set 13 | greytown
# Processing record 642 of set 13 | najran
# Processing record 643 of set 13 | broome
# Processing record 644 of set 13 | carlsbad
# Processing record 645 of set 13 | valley station
# Processing record 646 of set 13 | verdun
# Processing record 647 of set 13 | batagay-alyta
# Processing record 648 of set 13 | beloha
# Processing record 649 of set 13 | kieta
# Processing record 650 of set 13 | aklavik
# Processing record 651 of set 13 | huntsville
# Processing record 652 of set 13 | flinders
# Processing record 653 of set 13 | perth
# Processing record 654 of set 13 | plan-les-ouates
# Processing record 655 of set 13 | san juan
# Processing record 656 of set 13 | mizan teferi
# Processing record 657 of set 13 | kirando
# Processing record 658 of set 13 | avera
# Processing record 659 of set 13 | manggar
# Processing record 660 of set 13 | tunduru
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=tunduru
# Processing record 661 of set 13 | kitzbuhel
# Processing record 662 of set 13 | nyrob
# Processing record 664 of set 14 | fortuna
# Processing record 665 of set 14 | destin
# Processing record 666 of set 14 | bandarbeyla
# Processing record 667 of set 14 | mtambile
# Processing record 668 of set 14 | toftir
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=toftir
# Processing record 669 of set 14 | acari
# Processing record 670 of set 14 | mauswagon
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=mauswagon
# Processing record 671 of set 14 | omaruru
# Processing record 672 of set 14 | alassio
# Processing record 673 of set 14 | tual
# Processing record 674 of set 14 | sorab
# Processing record 675 of set 14 | caieiras
# Processing record 676 of set 14 | griffith
# Processing record 677 of set 14 | boyuibe
# Processing record 678 of set 14 | albania
# Processing record 679 of set 14 | adamas
# Processing record 680 of set 14 | andreapol
# Processing record 681 of set 14 | zverevo
# Processing record 682 of set 14 | worms
# Processing record 683 of set 14 | the pas
# Processing record 684 of set 14 | chitral
# Processing record 685 of set 14 | pocone
# Processing record 686 of set 14 | vikulovo
# Processing record 687 of set 14 | ust-kuyga
# Processing record 688 of set 14 | quatre cocos
# Processing record 689 of set 14 | inta
# Processing record 690 of set 14 | ouesso
# Processing record 691 of set 14 | temaraia
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=temaraia
# Processing record 692 of set 14 | azimur
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=azimur
# Processing record 693 of set 14 | huarmey
# Processing record 694 of set 14 | araceli
# Processing record 695 of set 14 | zemio
# Processing record 696 of set 14 | arnoldstein
# Processing record 697 of set 14 | dickinson
# Processing record 698 of set 14 | kinablangan
# Processing record 699 of set 14 | taltal
# Processing record 700 of set 14 | labutta
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=labutta
# Processing record 701 of set 14 | key largo
# Processing record 702 of set 14 | kumbakonam
# Processing record 703 of set 14 | buala
# Processing record 704 of set 14 | peniche
# Processing record 705 of set 14 | sakakah
# Processing record 706 of set 14 | souris
# Processing record 707 of set 14 | gat
# Processing record 708 of set 14 | ilhabela
# Processing record 709 of set 14 | rawson
# Processing record 710 of set 14 | linkou
# Processing record 711 of set 14 | tari
# Processing record 712 of set 14 | labytnangi
# Processing record 713 of set 14 | bathsheba
# Processing record 715 of set 15 | wenling
# Processing record 716 of set 15 | makokou
# Processing record 717 of set 15 | chalon-sur-saone
# Processing record 718 of set 15 | west wendover
# Processing record 719 of set 15 | yulara
# Processing record 720 of set 15 | bousse
# Processing record 721 of set 15 | shchuchye
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=shchuchye
# Processing record 722 of set 15 | mount gambier
# Processing record 723 of set 15 | asau
# Processing record 724 of set 15 | tura
# Processing record 725 of set 15 | harboore
# Processing record 726 of set 15 | brownsville
# Processing record 727 of set 15 | prince albert
# Processing record 728 of set 15 | santo augusto
# Processing record 729 of set 15 | samur
# Processing record 730 of set 15 | sanawad
# Processing record 731 of set 15 | tadpatri
# Processing record 732 of set 15 | visby
# Processing record 733 of set 15 | baghmara
# Processing record 734 of set 15 | pangai
# Processing record 735 of set 15 | cedar city
# Processing record 736 of set 15 | bouna
# Processing record 737 of set 15 | mikkeli
# Processing record 738 of set 15 | galesong
# Processing record 739 of set 15 | olinda
# Processing record 740 of set 15 | newburn
# Processing record 741 of set 15 | kuruman
# Processing record 742 of set 15 | aksarka
# Processing record 743 of set 15 | broken hill
# Processing record 744 of set 15 | grafton
# Processing record 745 of set 15 | koslan
# Processing record 746 of set 15 | carutapera
# Processing record 747 of set 15 | mayo
# Processing record 748 of set 15 | asfi
# Processing record 749 of set 15 | temixco
# Processing record 750 of set 15 | fraserburgh
# Processing record 751 of set 15 | sambava
# Processing record 752 of set 15 | dzhusaly
# Exception of type 'coord' has occurred: City not found. Skipping http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cffff8ff73a7168bf275736a072b77c&q=dzhusaly
# Processing record 753 of set 15 | necochea
# Processing record 754 of set 15 | toora-khem
# Processing record 755 of set 15 | bad bevensen
# Processing record 756 of set 15 | ust-ilimsk
# Processing record 757 of set 15 | haines junction
# Processing record 758 of set 15 | takoradi
# Processing record 759 of set 15 | freeport
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries into a data frame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Prince Rupert      CA  54.3161 -130.3201     42.89        93         100
# 1        Mataura      NZ -46.1927  168.8643     54.48        66          99
# 2          Kapaa      US  22.0752 -159.3190     82.38        86         100
# 3   Ponta Do Sol      PT  32.6667  -17.1000     61.43        75          50
# 4   Norman Wells      CA  65.2820 -126.8329     35.64        60         100
# 5         Hobart      AU -42.8794  147.3294     66.02        91          75
# 6          Pevek      RU  69.7008  170.3133     34.95        78         100
# 7           Hami      CN  42.8000   93.4500     60.40        20         100
# 8   Saint George      US  37.1041 -113.5841     85.62        10          75
# 9           Hilo      US  19.7297 -155.0900     84.27        78         100
#
#    Wind Speed Current Description
# 0        5.75          light rain
# 1        2.28     overcast clouds
# 2        3.00     overcast clouds
# 3        4.03    scattered clouds
# 4        5.75     overcast clouds
# 5        6.91       broken clouds
# 6       17.56     overcast clouds
# 7       14.00     overcast clouds
# 8        7.00       broken clouds
# 9        8.05     overcast clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
